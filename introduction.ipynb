# %% [markdown]
# # Audio Signal for Machine Learning

# %% [markdown]
# ## Introduction

# %% [markdown]
# #### Hey there! This notebook serves as an introduction to Librosa, a powerful Python library for audio analysis and music processing. It aims to provide a hands-on approach to understanding the digital representation of audio signals and the tools available for processing and analyzing them.

# %% [markdown]
# ### Signal Representation and Sampling
#
# - Sampling: In digital signal processing, we convert a continuous signal into a discrete signal by taking samples at specific intervals along the time axis. This process is called sampling, sampling essentially converts the signal into a series of data points taken at specific time intervals.
# - Quantization: After sampling, the signal undergoes a process called quantization, which involves converting the sampled values into discrete levels. This process is represented by indicating the transformation from continuous amplitude values (A) into discrete steps.
#
# ### The Nyquist-Shannon Theorem
# - The Nyquist-Shannon Theorem states that in order to accurately represent a signal, the sampling frequency must be at least twice the frequency of the highest frequency present in the signal. For audible sounds, humans can hear frequencies ranging from 20 Hz to 20 kHz, which means that the sampling frequency should be at least 40 kHz.

# %% [markdown]
# ### 1. Requirements

# %%
pip install librosa
# Out:
# Requirement already satisfied: librosa in /home/luigi/anaconda3/lib/python3.11/site-packages (0.10.2.post1)
# Requirement already satisfied: audioread>=2.1.9 in /home/luigi/anaconda3/lib/python3.11/site-packages (from librosa) (3.0.1)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in /home/luigi/anaconda3/lib/python3.11/site-packages (from librosa) (1.26.4)
# Requirement already satisfied: scipy>=1.2.0 in /home/luigi/anaconda3/lib/python3.11/site-packages (from librosa) (1.11.4)
# Requirement already satisfied: scikit-learn>=0.20.0 in /home/luigi/anaconda3/lib/python3.11/site-packages (from librosa) (1.2.2)
# Requirement already satisfied: joblib>=0.14 in /home/luigi/anaconda3/lib/python3.11/site-packages (from librosa) (1.2.0)
# Requirement already satisfied: decorator>=4.3.0 in /home/luigi/anaconda3/lib/python3.11/site-packages (from librosa) (5.1.1)
# Requirement already satisfied: numba>=0.51.0 in /home/luigi/anaconda3/lib/python3.11/site-packages (from librosa) (0.59.0)
# Requirement already satisfied: soundfile>=0.12.1 in /home/luigi/anaconda3/lib/python3.11/site-packages (from librosa) (0.13.0)
# Requirement already satisfied: pooch>=1.1 in /home/luigi/anaconda3/lib/python3.11/site-packages (from librosa) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /home/luigi/anaconda3/lib/python3.11/site-packages (from librosa) (0.5.0.post1)
# Requirement already satisfied: typing-extensions>=4.1.1 in /home/luigi/anaconda3/lib/python3.11/site-packages (from librosa) (4.9.0)
# Requirement already satisfied: lazy-loader>=0.1 in /home/luigi/anaconda3/lib/python3.11/site-packages (from librosa) (0.3)
# Requirement already satisfied: msgpack>=1.0 in /home/luigi/anaconda3/lib/python3.11/site-packages (from librosa) (1.0.3)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in /home/luigi/anaconda3/lib/python3.11/site-packages (from numba>=0.51.0->librosa) (0.42.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /home/luigi/anaconda3/lib/python3.11/site-packages (from pooch>=1.1->librosa) (3.10.0)
# Requirement already satisfied: packaging>=20.0 in /home/luigi/anaconda3/lib/python3.11/site-packages (from pooch>=1.1->librosa) (23.1)
# Requirement already satisfied: requests>=2.19.0 in /home/luigi/anaconda3/lib/python3.11/site-packages (from pooch>=1.1->librosa) (2.31.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/luigi/anaconda3/lib/python3.11/site-packages (from scikit-learn>=0.20.0->librosa) (2.2.0)
# Requirement already satisfied: cffi>=1.0 in /home/luigi/anaconda3/lib/python3.11/site-packages (from soundfile>=0.12.1->librosa) (1.16.0)
# Requirement already satisfied: pycparser in /home/luigi/anaconda3/lib/python3.11/site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/luigi/anaconda3/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/luigi/anaconda3/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/luigi/anaconda3/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /home/luigi/anaconda3/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2024.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import librosa
import librosa.display
import numpy as np
import matplotlib.pyplot as plt

# %%
# Carregar exemplo de áudio
audio_path = librosa.example('trumpet')
y, sr = librosa.load(audio_path)

# %%
# Reproduzir o áudio
import IPython.display as ipd
ipd.Audio(y, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### 2. Visualization / Audio Features

# %% [markdown]
# #### 2.1. Waveform - Time Domain

# %% [markdown]
# ##### y(t) = Asin(2πft + phi) - A: amplitude | f: frequence | phi: phase

# %%
plt.figure(figsize=(10, 4))
librosa.display.waveshow(y, sr=sr)
plt.title("Wave form")
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")
plt.show()

# %% [markdown]
# #### 2.2. Spectrogram

# %%
D = librosa.stft(y)  # Transformada de Fourier
S_db = librosa.amplitude_to_db(np.abs(D), ref=np.max)

plt.figure(figsize=(10, 4))
librosa.display.specshow(S_db, sr=sr, x_axis='time', y_axis='hz', cmap='magma')
plt.colorbar(format='%+2.0f dB')
plt.title(f"Log-frequency power spectrogram for trumpet")
plt.show()

# %% [markdown]
# #### 2.3. Mel-Spectogram

# %%
mel = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=128, fmax=8000)
mel_db = librosa.power_to_db(mel, ref=np.max)

plt.figure(figsize=(10, 4))
librosa.display.specshow(mel_db, sr=sr, x_axis='time', y_axis='mel', cmap='magma')
plt.colorbar(format='%+2.0f dB')
plt.title("Mel-Spectrogram")
plt.show()

# %% [markdown]
# #### 2.4. MFCCs Extraction

# %%
mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=13)

plt.figure(figsize=(10, 4))
librosa.display.specshow(mfccs, sr=sr, x_axis='time')
plt.colorbar()
plt.title("MFCCs")
plt.show()

# %% [markdown]
# #### 2.5. Rhythm Detection (BPM)

# %%
tempo, _ = librosa.beat.beat_track(y=y, sr=sr)
print(f"Tempo estimado: {tempo} BPM")
# Out:
# Tempo estimado: [184.5703125] BPM

# %% [markdown]
# #### 2.6. Pitch and Speed

# %% [markdown]
# ##### Changing the Pitch - Raising by 4 Semitones

# %%
y_shifted = librosa.effects.pitch_shift(y, sr=sr, n_steps=4) 
ipd.Audio(y_shifted, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ##### Changing the Speed - Slowing Down (80% of the original)

# %%
y_stretched = librosa.effects.time_stretch(y, rate=0.8)  
ipd.Audio(y_stretched, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# #### 2.7. Magnitude Spectrum - Frequence Domain

# %%
X = np.fft.fft(y)

# %%
X_mag = np.absolute(X)
f = np.linspace(0, sr, len(X_mag))

# %%
plt.figure(figsize=(18, 10))
plt.plot(f, X_mag) # magnitude spectrum
plt.xlabel('Frequency (Hz)')
# Out:
# Text(0.5, 0, 'Frequency (Hz)')
